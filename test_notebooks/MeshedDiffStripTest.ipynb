# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12,12]

import pala
import numpy as np

hl=pala.tlines.MeshedDiffStrip()
hl.mesh.size=6
hl.mesh.cut_size=3
hl.mesh.nx=9
hl.mesh.ny=3
hl.view()
