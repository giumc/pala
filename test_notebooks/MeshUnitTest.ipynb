# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12,12]

import pala
import numpy as np
hl=pala.tlines.Mesh()
hl.metal_size=(8,12)
hl.cut_size=(3,5)
# hl.layer=4
hl.metal_layer=2
hl.nx=8
hl.ny=3
hl.view()
# print(hl)
