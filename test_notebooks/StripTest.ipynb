# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12,12]

import pala
import numpy as np
hl=pala.tlines.Strip()
hl.layer=1
hl.w=10
hl.l=200
hl.view()

# %%
import phidl

help(phidl.geometry.compass)
# Out:
# Help on function compass in module phidl.geometry:
#
# compass(size=(4, 2), layer=0)
#     Creates a rectangular contact pad with centered ports on edges of the
#     rectangle (north, south, east, and west).
#
#     Parameters
#     ----------
#     size : array_like[2]
#         Dimensions of the rectangular contact pad.
#     layer : int, array-like[2], or set
#         Specific layer(s) to put polygon geometry on.
#
#     Returns
#     -------
#     D : Device
#         A Device containing a rectangular contact pad with centered ports.
